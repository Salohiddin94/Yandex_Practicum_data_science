# %% [markdown]
# # Проект: Обучение с учителем: качество модели
#
#  ## Описание проекта
#
#  Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#  «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
#  Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# ## Как решать задачу
#
#  Продумывать подход к решению этой задачи вам не придётся — руководитель отдела его уже сформировал:
#
#  1. Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
#  2. Нужно собрать данные по клиентам по следующим группам:
#    - Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
#    - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
#    - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
#    - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит  на сайте.
#
#  1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
#  2. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
#  3. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
# Руководство одобрило описание решения, и вам, как специалисту по DS, нужно его реализовать.

# %% [markdown]
# ## Описание данных
#
# Данные для работы находятся в нескольких таблицах. Нажмите на название файла, чтобы его скачать.
#
# market_file.csv
#
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
# - id — номер покупателя в корпоративной базе данных.
# - Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
# - Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# - Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
# - Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# market_money.csv
#
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - Выручка — сумма выручки за период.
#
# market_time.csv
#
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксировано общее время.
# - минут — значение времени, проведённого на сайте, в минутах.
#
# money.csv
#
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
# - id — номер покупателя в корпоративной базе данных.
# - Прибыль — значение прибыли.

# %% [markdown]
# ## Инструкция по выполнению проекта
#
# Решать задачу вам нужно в два этапа:
#
# 1. Разработайте модель, которая предскажет вероятность снижения покупательской активности.
# 2. Выделите сегмент покупателей, проанализируйте его и предложите, как увеличить его покупательскую активность. Используйте данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся). По желанию вы можете проанализировать больше одного сегмента.
#
# Ниже несколько примеров сегментов, но вы также можете выделить свой:
#
#  - Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
#  - Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
#  - Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
#  - Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %% [markdown]
# ## Цель исследования
#
#  Цель исследования — разработать модель машинного обучения, которая предскажет вероятность снижения покупательской активности постоянных клиентов интернет-магазина «В один клик». На основе этой модели планируется создать сегментацию клиентов для разработки персонализированных предложений, что позволит удерживать клиентов и увеличивать их покупательскую активность.
#
# ## Ход исследования:
#
#    1. Сбор и предварительная обработка данных.
#    2. Анализ и визуализация данных.
#    3. Построение и обучение моделей.
#    4. Анализ важности признаков.
#    5. Сегментация покупателей.
#    6. Общий вывод.

# %%
# ! pip install -Uq scikit-learn
# ! pip install matplotlib==3.5.0 -q
# ! pip install phik shap -q

# %%
# импорт библиотеки
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score

import shap

from phik.report import plot_correlation_matrix
from phik import report

import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# ### 1.1 Загрузите данные. Файлы market_file.csv, market_money.csv, market_time.csv, money.csv.

# %%
market_file_df = pd.read_csv('https://code.s3.yandex.net/datasets/market_file.csv', delimiter=',', decimal='.')
market_money_df = pd.read_csv('https://code.s3.yandex.net/datasets/market_money.csv', delimiter=',', decimal='.')
market_time_df = pd.read_csv('https://code.s3.yandex.net/datasets/market_time.csv', delimiter=',', decimal='.')
money_df = pd.read_csv('https://code.s3.yandex.net/datasets/money.csv', delimiter=';', decimal=',')

# %% [markdown]
# ### 1.2 Проверьте, что данные в таблицах соответствуют описанию. Исследованием и объединением данных вы займётесь позже.

# %%
market_file_df.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
market_file_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
market_money_df.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
market_money_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_time_df.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
market_time_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
money_df.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %%
money_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# <b>Вывод</b>
#
# - Данные соответствуют по описанию задачи.
# - В датасетах есть  количественные и категориальные признаки.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### Проведите необходимую предобработку данных. Названия столбцов можно оставить кириллическими.

# %%
#количество пропущенных значений
market_file_df.isna().sum()
# Out:
# id                                     0
# Покупательская активность              0
# Тип сервиса                            0
# Разрешить сообщать                     0
# Маркет_актив_6_мес                     0
# Маркет_актив_тек_мес                   0
# Длительность                           0
# Акционные_покупки                      0
# Популярная_категория                   0
# Средний_просмотр_категорий_за_визит    0
# Неоплаченные_продукты_штук_квартал     0
# Ошибка_сервиса                         0
# Страниц_за_визит                       0
# dtype: int64

# %%
#количество пропущенных значений
market_money_df.isna().sum()
# Out:
# id         0
# Период     0
# Выручка    0
# dtype: int64

# %%
#количество пропущенных значений
market_time_df.isna().sum()
# Out:
# id        0
# Период    0
# минут     0
# dtype: int64

# %%
#количество пропущенных значений
money_df.isna().sum()
# Out:
# id         0
# Прибыль    0
# dtype: int64

# %%
# переименование столбцов
market_file_df.columns=market_file_df.columns.str.lower()
market_money_df.columns=market_money_df.columns.str.lower()
market_time_df.columns=market_time_df.columns.str.lower()
money_df.columns=money_df.columns.str.lower()

# %%
print('подсчёт явных дубликатов market_file_df:',market_file_df.duplicated().sum())
print('подсчёт явных дубликатов market_money_df:',market_money_df.duplicated().sum())
print('подсчёт явных дубликатов market_time_df:',market_time_df.duplicated().sum())
print('подсчёт явных дубликатов money_df:',money_df.duplicated().sum())
# Out:
# подсчёт явных дубликатов ferma_main_df: 0
# подсчёт явных дубликатов ferma_dad_df: 0
# подсчёт явных дубликатов cow_buy_df: 0
# подсчёт явных дубликатов cow_buy_df: 0

# %%
# Уникальные значения по категориальным значениям market_file_df
cat_col=market_file_df.select_dtypes(include=['object'])
for column in cat_col:
    print(column)
    print(market_file_df[column].unique())
    print()
# Out:
# покупательская активность
# ['Снизилась' 'Прежний уровень']
#
# тип сервиса
# ['премиум' 'стандартт' 'стандарт']
#
# разрешить сообщать
# ['да' 'нет']
#
# популярная_категория
# ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']

# %%
# Уникальные значения по категориальным значениям market_money_df
cat_col=market_money_df.select_dtypes(include=['object'])
for column in cat_col:
    print(column)
    print(market_money_df[column].unique())
    print()
# Out:
# период
# ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']

# %%
# Уникальные значения по категориальным значениям market_time_df
cat_col=market_time_df.select_dtypes(include=['object'])
for column in cat_col:
    print(column)
    print(market_time_df[column].unique())
    print()
# Out:
# период
# ['текущий_месяц' 'предыдцщий_месяц']

# %% [markdown]
# Из данных можно наблюдать что значения 'стандартт' 'стандарт' , 'предыдущий_месяц' 'предыдцщий_месяц' неявные дубликаты.

# %%
# удалим неявные дубликаты
market_file_df['тип сервиса'] = market_file_df['тип сервиса'].replace('стандартт','стандарт')
market_time_df['период'] = market_time_df['период'].replace('предыдцщий_месяц','предыдущий_месяц')

# %% [markdown]
# <b>Вывод</b>
#
# В ходе предобработки данных:
#
# - Проверена наличие пропущенных значений к счастью их нет.
# - Убрали дубликатов в датафреймах.
# - Удалили неявные дубликаты.
# - Переименовали столбцы.

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### Проведите исследовательский анализ данных из каждой таблицы. Отберите клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Оформите выводы по результатам шага.

# %%
# Сделаем id индексом.
market_file_df=market_file_df.set_index('id')
market_money_df=market_money_df.set_index('id')
market_time_df=market_time_df.set_index('id')
money_df=money_df.set_index('id')

# %%
# Cтатистический анализ для числовых признаков market_file_df
market_file_df.describe()
# Out:
#        маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# count         1300.000000           1300.000000   1300.000000
# mean             4.253769              4.011538    601.898462
# std              1.014814              0.696868    249.856289
# min              0.900000              3.000000    110.000000
# 25%              3.700000              4.000000    405.500000
# 50%              4.200000              4.000000    606.000000
# 75%              4.900000              4.000000    806.000000
# max              6.600000              5.000000   1079.000000
#
#        акционные_покупки  средний_просмотр_категорий_за_визит  \
# count        1300.000000                           1300.00000
# mean            0.319808                              3.27000
# std             0.249843                              1.35535
# min             0.000000                              1.00000
# 25%             0.170000                              2.00000
# ...

# %%
# Cтатистический анализ для категориальных признаков market_file_df
market_file_df.describe(include=['object'])
# Out:
#        покупательская активность тип сервиса разрешить сообщать  \
# count                       1300        1300               1300
# unique                         2           2                  2
# top              Прежний уровень    стандарт                 да
# freq                         802         924                962
#
#        популярная_категория
# count                  1300
# unique                    6
# top        Товары для детей
# freq                    330

# %%
# построим графики по количественным признакам market_file_df датасета
# гистограмму частотности распределения и ящик с усами. 
num_col=market_file_df.select_dtypes(include=['int64', 'float64'])
cat_col=market_file_df.select_dtypes(include=['object'])

for n_col in num_col:
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        sns.histplot(market_file_df[n_col], kde=True)
        plt.title(f'Гистограмма {n_col}')

        plt.subplot(1, 2, 2)
        sns.boxplot(y=market_file_df[n_col])
        plt.title(f'Разброс значений признака {n_col}')
        plt.show()

# %% [markdown]
# <b>Вывод</b>
# - В признаках маркет_актив_6_мес, акционные_покупки, неоплаченные_продукты_штук_квартал наблюдается выбросы.

# %%
# построим графики по категориальним признакам market_file_df датасета
# столбчатая и круговая диаграмма. 
num_col=market_file_df.select_dtypes(include=['int64', 'float64'])
cat_col=market_file_df.select_dtypes(include=['object'])

for c_col in cat_col:
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        sns.countplot(y=market_file_df[c_col])
        plt.title(f'Столбчатая диаграмма {c_col}')
        
        plt.subplot(1, 2, 2)
        market_file_df[c_col].value_counts().plot.pie(autopct='%1.1f%%')
        plt.title(f'Круговая диаграмма {c_col}')
        plt.show()

# %% [markdown]
# <b>Вывод</b>
# - В признаках тип сервиса, разрешить сообщать и покупательская активность наблюдается дисбаланс в значениях.

# %%
# Cтатистический анализ для числовых признаков market_money_df
market_money_df.describe()
# Out:
#              выручка
# count    3900.000000
# mean     5025.696051
# std      1777.704104
# min         0.000000
# 25%      4590.150000
# 50%      4957.500000
# 75%      5363.000000
# max    106862.200000

# %%
# Cтатистический анализ для категориальных признаков market_money_df
market_money_df.describe(include=['object'])
# Out:
#                      период
# count                  3900
# unique                    3
# top     препредыдущий_месяц
# freq                   1300

# %%
# построим графики по количественным признакам market_money_df датасета
# гистограмму частотности распределения и ящик с усами. 
num_col=market_money_df.select_dtypes(include=['int64', 'float64'])
cat_col=market_money_df.select_dtypes(include=['object'])

for n_col in num_col:
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        sns.histplot(market_money_df[n_col], kde=True)
        plt.title(f'Гистограмма {n_col}')

        plt.subplot(1, 2, 2)
        sns.boxplot(y=market_money_df[n_col])
        plt.title(f'Разброс значений признака {n_col}')
        plt.show()

# %% [markdown]
# В признак выручка наблюдается выброс слишком большое значения и 0. Удалим этих значений

# %%
#Удалим выбросы
market_money_df=market_money_df[market_money_df['выручка']!=market_money_df['выручка'].max()]
market_money_df=market_money_df[market_money_df['выручка']!=0]

# %%
sns.boxplot(y=market_money_df['выручка'])
plt.title('Разброс значений признака выручка')
plt.show()

# %%
# построим графики по категориальним признакам market_money_df датасета
# столбчатая и круговая диаграмма. 
num_col=market_money_df.select_dtypes(include=['int64', 'float64'])
cat_col=market_money_df.select_dtypes(include=['object'])

for c_col in cat_col:
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        sns.countplot(y=market_money_df[c_col])
        plt.title(f'Столбчатая диаграмма {c_col}')
        
        plt.subplot(1, 2, 2)
        market_money_df[c_col].value_counts().plot.pie(autopct='%1.1f%%')
        plt.title(f'Круговая диаграмма {c_col}')
        plt.show()

# %% [markdown]
# <b>Вывод</b>
# - Удалили выбросы.

# %%
# Cтатистический анализ для числовых признаков market_time_df
market_time_df.describe()
# Out:
#              минут
# count  2600.000000
# mean     13.336154
# std       4.080198
# min       4.000000
# 25%      10.000000
# 50%      13.000000
# 75%      16.000000
# max      23.000000

# %%
# Cтатистический анализ для категориальных признаков market_time_df
market_time_df.describe(include=['object'])
# Out:
#                период
# count            2600
# unique              2
# top     текущий_месяц
# freq             1300

# %%
# построим графики по количественным признакам market_time_df датасета
# гистограмму частотности распределения и ящик с усами. 
num_col=market_time_df.select_dtypes(include=['int64', 'float64'])
cat_col=market_time_df.select_dtypes(include=['object'])

for n_col in num_col:
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        sns.histplot(market_time_df[n_col], kde=True)
        plt.title(f'Гистограмма {n_col}')

        plt.subplot(1, 2, 2)
        sns.boxplot(y=market_time_df[n_col])
        plt.title(f'Разброс значений признака {n_col}')
        plt.show()

# %%
# построим графики по категориальним признакам market_time_df датасета
# столбчатая и круговая диаграмма. 
num_col=market_time_df.select_dtypes(include=['int64', 'float64'])
cat_col=market_time_df.select_dtypes(include=['object'])

for c_col in cat_col:
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        sns.countplot(y=market_time_df[c_col])
        plt.title(f'Столбчатая диаграмма {c_col}')
        
        plt.subplot(1, 2, 2)
        market_time_df[c_col].value_counts().plot.pie(autopct='%1.1f%%')
        plt.title(f'Круговая диаграмма {c_col}')
        plt.show()

# %%
# Cтатистический анализ для числовых признаков money_df
money_df.describe()
# Out:
#            прибыль
# count  1300.000000
# mean      3.996631
# std       1.013722
# min       0.860000
# 25%       3.300000
# 50%       4.045000
# 75%       4.670000
# max       7.430000

# %%
num_col=num_col=money_df.select_dtypes(include=['int64', 'float64'])
for n_col in num_col:
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        sns.histplot(money_df[n_col], kde=True)
        plt.title(f'Гистограмма {n_col}')

        plt.subplot(1, 2, 2)
        sns.boxplot(y=money_df[n_col])
        plt.title(f'Разброс значений признака {n_col}')
        plt.show()

# %% [markdown]
# <b>Вывод</b>
# - В признак прибыль наблюдается выбросы.

# %%
money_df.min()
# Out:
# прибыль    0.86
# dtype: float64

# %% [markdown]
# Минимальная значения прибыль больше нуля и это означает что все ползователи совершили покупку в этих периодах.

# %% [markdown]
# <b>Вывод</b>
#
# - Удалили выбросы.
# - В некоторих признаках наблюдается выбросы и дисбаланс класса.
# - Все покупатели совершили покупки в указанних периодах.

# %% [markdown]
# ## Шаг 4. Объединение таблиц

# %% [markdown]
# ### 4.1 Объедините таблицы market_file.csv, market_money.csv, market_time.csv. Данные о прибыли из файла money.csv при моделировании вам не понадобятся.

# %% [markdown]
# ### 4.2 Учитывайте, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделайте отдельный столбец для каждого периода.

# %%
#Объединим таблиц
market_money_pivot = market_money_df.pivot( columns='период', values='выручка')
market_money_pivot.columns = ['период_выручка' + col for col in market_money_pivot.columns]

market_time_pivot = market_time_df.pivot(columns='период', values='минут')
market_time_pivot.columns = ['период_минут' + col for col in market_time_pivot.columns]

market_full_df = market_file_df.merge(market_money_pivot, on='id', how='left')
market_full_df = market_full_df.merge(market_time_pivot, on='id', how='left')

# %%
market_full_df.head()
# Out:
#        покупательская активность тип сервиса разрешить сообщать  \
# id
# 215348                 Снизилась     премиум                 да
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась    стандарт                нет
# 215351                 Снизилась    стандарт                 да
# 215352                 Снизилась    стандарт                нет
#
#         маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# id
# 215348                 3.4                     5           121
# 215349                 4.4                     4           819
# 215350                 4.9                     3           539
# 215351                 3.2                     5           896
# 215352                 5.1                     3          1064
#
#         акционные_покупки популярная_категория  \
# id
# 215348               0.00     Товары для детей
# 215349               0.75     Товары для детей
# ...

# %%
#Удалим NaN значений
market_full_df=market_full_df.dropna()

# %%
market_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 215349 to 216647
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   покупательская активность            1296 non-null   object
#  1   тип сервиса                          1296 non-null   object
#  2   разрешить сообщать                   1296 non-null   object
#  3   маркет_актив_6_мес                   1296 non-null   float64
#  4   маркет_актив_тек_мес                 1296 non-null   int64
#  5   длительность                         1296 non-null   int64
#  6   акционные_покупки                    1296 non-null   float64
#  7   популярная_категория                 1296 non-null   object
#  8   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  9   неоплаченные_продукты_штук_квартал   1296 non-null   int64
#  10  ошибка_сервиса                       1296 non-null   int64
# ...

# %% [markdown]
# <b>Вывод</b>
#
# - Объединили таблицы.
# - Удалили NaN значений.
# - Переименовали одинаковые столбцы

# %% [markdown]
# ## Шаг 5. Корреляционный анализ

# %% [markdown]
# ### Проведите корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделайте выводы о мультиколлинеарности и при необходимости устраните её.

# %%
market_full_df['покупательская активность']=np.where(market_full_df['покупательская активность']=='Снизилась',1,0)

# %%
# список интервальных признаков
interval_cols = market_full_df.select_dtypes(include=['number']).columns.to_list()
interval_cols.remove('покупательская активность') # Это категория

# вычисление коэффициентов корреляции phi для датафрейма df
phik_overview = market_full_df.phik_matrix(interval_cols=interval_cols)

# визуализация тепловой карты коэффициентов корреляции
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r"correlation $\phi_K$",
    fontsize_factor=1.5,
    figsize=(15, 12)
)

# %% [markdown]
# <font color='blue'><b>Теория </b></font> ⚠️\
# <font color='darkorange'>Здесь Лучше посмотреть все признаки, включая Таргет.\
# Хорошим решением будет использовать коэффициент корреляции $\phi_K$ , это передовой способ вычисления коэффициентов корреляции для любых типов признаков и не требует предварительного кодирования. Кроме того, в библиотеке есть визуализация. Стоит учитывать, что этот коэффициент показывает не только линейные связи, но и нелинейные. Более подробно понять вид связи поможет визуализация с помощью диаграмм рассеяния. Ссылка на документацию: https://phik.readthedocs.io/en/latest/
# Пример кода:</font>
# ```python
# from phik.report import plot_correlation_matrix
# from phik import report
#
# # список интервальных признаков
# interval_cols = [...]
#
# # вычисление коэффициентов корреляции phi для датафрейма df
# phik_overview = df.phik_matrix(interval_cols=interval_cols)
#
# # визуализация тепловой карты коэффициентов корреляции
# plot_correlation_matrix(
#     phik_overview.values,
#     x_labels=phik_overview.columns,
#     y_labels=phik_overview.index,
#     title=r"correlation $\phi_K$",
#     fontsize_factor=1.5,
#     figsize=(15, 12)
# )
# ```

# %%
num_col=market_full_df.select_dtypes(include=['number']).columns
for n_col in num_col:
    )plt.figure(figsize=(10, 6))
    sns.histplot(data=market_full_df, x=n_col, hue='покупательская активность', kde=True, element='step')
    plt.title(f'Распределение {n_col} в зависимости от покупательская активность')
    plt.show(

# %%
# Удалим признак период_выручкапрепредыдущий_месяц потомучто наблюдается мултиколлинеарность.
market_full_df=market_full_df.drop(['период_выручкапрепредыдущий_месяц'],axis=1)

# %% [markdown]
# <b>Вывод</b>
#
# - По шкале Чеддока высокая связ между целевым признакам и признак страниц_за_визит.
# -  Мультиколлинеарность наблюдается между признак период_выручкапредыдущий_месяц и период_выручкапрепредыдущий_месяц.
# - По графикам можем наблюдать покупательная активность не снизилось.
# - Удалили признак из-за высокая значения корреляция.

# %% [markdown]
# ## Шаг 6. Использование пайплайнов

# %% [markdown]
# ### 6.1 Во время подготовки данных используйте ColumnTransformer. Количественные и категориальные признаки обработайте в пайплайне раздельно. Для кодирования категориальных признаков используйте как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера. Напоминаем, что для каждой модели можно подготовить данные с разным кодированием и масштабированием.

# %% [markdown]
# ### 6.2 Обучите четыре модели: KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и  SVC(). Для каждой из них подберите как минимум один гиперпараметр. Выберите подходящую для задачи метрику, аргументируйте свой выбор. Используйте эту метрику при подборе гиперпараметров.

# %% [markdown]
# ### 6.3 Выберите лучшую модель, используя заданную метрику. Для этого примените одну из стратегий:
#  - использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель самостоятельно;
#  - использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернёт вам лучшую модель.

# %%
market_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 215349 to 216647
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   покупательская активность            1296 non-null   int32
#  1   тип сервиса                          1296 non-null   object
#  2   разрешить сообщать                   1296 non-null   object
#  3   маркет_актив_6_мес                   1296 non-null   float64
#  4   маркет_актив_тек_мес                 1296 non-null   int64
#  5   длительность                         1296 non-null   int64
#  6   акционные_покупки                    1296 non-null   float64
#  7   популярная_категория                 1296 non-null   object
#  8   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  9   неоплаченные_продукты_штук_квартал   1296 non-null   int64
#  10  ошибка_сервиса                       1296 non-null   int64
# ...

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25
X=market_full_df.drop(['покупательская активность'], axis=1)
y=market_full_df['покупательская активность']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = TEST_SIZE,  random_state = RANDOM_STATE,stratify = y)

ohe_columns = ['тип сервиса','разрешить сообщать','популярная_категория']
#ord_columns = ['тип сервиса']
num_columns = ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность','акционные_покупки','средний_просмотр_категорий_за_визит',
'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса','страниц_за_визит', 'период_выручкапредыдущий_месяц',
'период_выручкатекущий_месяц', 'период_минутпредыдущий_месяц','период_минуттекущий_месяц']

ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )
# ord_pipe = Pipeline(
#     [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
#      ('ord',  OrdinalEncoder(
#                 handle_unknown='use_encoded_value', unknown_value=np.nan
#             )
#         ),
#      ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
#     ]
# )


data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     #('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 10),
        'models__max_features': range(2, 15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 200),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]  
    },
    {
        'models': [SVC(probability=True,random_state=RANDOM_STATE)],
        'models__kernel': ['linear', 'rbf'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]
    }
]

randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)

y_test_proba = randomized_search.predict_proba(X_test)
y_test_proba_one = y_test_proba[:, 1]
print('Площадь ROC-кривой:', roc_auc_score(y_test, y_test_proba_one))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('ohe',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  keep_empty_features=False,
# ...

# %% [markdown]
# <b>Вывод</b>
#
# - Лучшая модел KNeighborsClassifier с параметрами n_neighbors=141 и метрика на тесте roc_auc_score=0.91.
# - Выбрали метрика roc_auc из-за дисбаланса значений таргета.
# - На модели деревя решений и knn выбрали большие диапазон значений гиперпараметры чтобы оценить качество. Это очень помогло на метрику.

# %% [markdown]
# ## Шаг 7. Анализ важности признаков

# %% [markdown]
# ### 7.1 Оцените важность признаков для лучшей модели и постройте график важности с помощью метода SHAP.

# %%
# Подготовим данные с лучшей моделю для использования метода shap
best_model = randomized_search.best_estimator_.named_steps['models']
preprocessor = randomized_search.best_estimator_.named_steps['preprocessor']
X_train_preprocessored = preprocessor.transform(X_train)
X_test_preprocessored = preprocessor.transform(X_test)
ohe_feature_names = preprocessor.named_transformers_['ohe'].get_feature_names_out(input_features=ohe_columns)
full_feature_names = np.concatenate([ohe_feature_names, num_columns])
X_train_preprocessored_df = pd.DataFrame(X_train_preprocessored, columns=full_feature_names)
X_test_preprocessored_df = pd.DataFrame(X_test_preprocessored, columns=full_feature_names)

# %%
# Построим график важности признаков
X_train_sample = shap.sample(X_train_preprocessored_df, 10, random_state=RANDOM_STATE)
X_test_sample = shap.sample(X_test_preprocessored_df, 10, random_state=RANDOM_STATE)
explainer = shap.KernelExplainer(best_model.predict_proba, X_test_sample)
shap_values = explainer(X_test_sample)
shap.summary_plot(shap_values[...,1], X_test_sample,feature_names=full_feature_names)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### 7.2 Сделайте выводы о значимости признаков:
#   - какие признаки мало значимы для модели;
#   - какие признаки сильнее всего влияют на целевой признак;
#   - как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.

# %%
#график shap bar
shap.plots.bar(shap_values[...,1])

# %% [markdown]
# <b>Вывод</b>
#
# Столбчатая диаграмма shap.plots.bar отражает общий вклад признаков в прогнозы модели. Она показывает средние SHAP-значения признака по всем наблюдениям. Для расчёта средних берут значения Шепли по модулю, чтобы положительные и отрицательные значения не сводили друг друга к нулю.
#
# Каждому признаку соответствует свой столбец диаграммы, его размер отражает среднее SHAP‑значение по признаку.
#
# - На датасете самый большой вес у признака период_минуттекущий_месяц, он сильнее всего влияет на прогнозы модели..
# - На датасете мало значимые вес у признака популярная_категория.
# - Вычисление значений Шепли позволяет более точно оценивать вклад признаков как на все решения модели, так и для каждого конкретного наблюдения.

# %% [markdown]
# ## Шаг 8. Сегментация покупателей

# %% [markdown]
# ### 8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.

# %% [markdown]
# Анализируем сегмента "Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом."

# %%
#Используем лучший модель для прогноза
best_model = randomized_search.best_estimator_
market_full_df['y_proba'] = best_model.predict_proba(X)[:, 1]

# Объединим данных
segment_df = market_full_df.merge(money_df, on='id', how='left')

# %%
# Построение диаграммы рассеяния
plt.figure(figsize=(10, 6))
sns.scatterplot(x='y_proba', y='прибыль', data=segment_df, hue='покупательская активность', palette='coolwarm')
plt.title('Сегментация клиентов')
plt.xlabel('Вероятность снижения активности')
plt.ylabel('Прибыль')
plt.legend()
plt.show()

# %%
#выберим ту часть где больше снижение активности и высокий прибыль
segment_prob_df=segment_df[(segment_df['y_proba']>0.65)& (segment_df['прибыль'] >2.3)]
segment_prob_df.head()
# Out:
#         покупательская активность тип сервиса разрешить сообщать  \
# id
# 215349                          1     премиум                 да
# 215352                          1    стандарт                нет
# 215356                          1    стандарт                 да
# 215364                          1     премиум                 да
# 215365                          1    стандарт                 да
#
#         маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# id
# 215349                 4.4                     4           819
# 215352                 5.1                     3          1064
# 215356                 4.2                     4           192
# 215364                 4.3                     4           708
# 215365                 3.9                     4           167
#
#         акционные_покупки            популярная_категория  \
# id
# 215349               0.75                Товары для детей
# 215352               0.94                Товары для детей
# ...

# %%
#Проверка датасета
segment_prob_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 215349 to 215910
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   покупательская активность            245 non-null    int32
#  1   тип сервиса                          245 non-null    object
#  2   разрешить сообщать                   245 non-null    object
#  3   маркет_актив_6_мес                   245 non-null    float64
#  4   маркет_актив_тек_мес                 245 non-null    int64
#  5   длительность                         245 non-null    int64
#  6   акционные_покупки                    245 non-null    float64
#  7   популярная_категория                 245 non-null    object
#  8   средний_просмотр_категорий_за_визит  245 non-null    int64
#  9   неоплаченные_продукты_штук_квартал   245 non-null    int64
#  10  ошибка_сервиса                       245 non-null    int64
# ...

# %% [markdown]
# ### 8.2 Выберите группу покупателей и предложите, как увеличить её покупательскую активность: Проведите графическое и аналитическое исследование группы покупателей.Сделайте предложения по работе с сегментом для увеличения покупательской активности.

# %% [markdown]
# Используем признак страниц_за_визит для анализа.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(segment_prob_df['страниц_за_визит'], kde=True, element='step')
plt.title('Распределение признака страниц_за_визит')
plt.show()

# %%
num_col=['акционные_покупки','средний_просмотр_категорий_за_визит','период_минутпредыдущий_месяц','период_минуттекущий_месяц']
for n_col in num_col:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=segment_prob_df, x=n_col, hue='страниц_за_визит', kde=True, element='step')
    plt.title(f'Распределение {n_col} в зависимости от страниц_за_визит')
    plt.show()

# %% [markdown]
# <b>Вывод</b>
#
# -  Графики распределены не симметрично.

# %% [markdown]
# ### 8.3 Сделайте выводы о сегментах:
#  - какой сегмент вы взяли для дополнительного исследования,
#  - какие предложения вы сделали и почему.

# %% [markdown]
# - Выбрал сегмент, которые имеют высокую вероятность снижения покупательской активности и при этом приносят высокую прибыль компании. Такой сегмент особенно важен для бизнеса, так как потеря этих клиентов может существенно снизить общий доход.
# - Рекомендую:
#    - информировать клиентов о новых продуктах, скидках и акциях.
#    - предоставлять эксклюзивных скидок и предложений, основанных на истории покупок и интересах клиентов.

# %% [markdown]
# ## Шаг 9. Общий вывод

# %% [markdown]
# ### Сделайте общий вывод:
#   - опишите задачу;
#   - опишите исходные данные и проведённую предобработку;
#   - напишите, что вы сделали для поиска лучшей модели;
#   - укажите лучшую модель;
#   - добавьте выводы и дополнительные предложения для выбранного сегмента покупателей.

# %% [markdown]
# - Разработали модель машинного обучения, которая предскажет вероятность снижения покупательской активности постоянных клиентов интернет-магазина «В один клик».
#
# - Провели предобработку данных: переименовали столбцы, удалили неявные дубликаты, проверили соответствия данных.
#
# - Для поиска лучшего моделя использовали пайплан с гиперпараметрами модели KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и  SVC() и поиска лучшего параметра RandomizedSearchCV.
#
# - Лучший модель  KNeighborsClassifier с параметрами n_neighbors=141 и метрика на тесте roc_auc_score=0.91.
#
# - Выбранный сегмент клиентов представляет значительную ценность для бизнеса, поэтому важно уделить особое внимание разработке стратегий для их удержания и увеличения покупательской активности.
