# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd

data = pd.read_csv('https://code.s3.yandex.net/datasets/data.csv')

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.368353
# компаньон            1547.382223
# пенсионер          365213.306266
# предприниматель       520.848083
# сотрудник            1574.202821
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть. Тем более этот столбец не понадобится вам для исследования.

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5], dtype=int64)

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
data = data[(data['children'] != -1) & (data['children'] != 20)]

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5], dtype=int64)

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру. Проверьте остальные столбцы.**

# %%
data['education'] = data['education'].str.lower()

# %% [markdown]
# **Задание 15. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 71

# %%
data = data.drop_duplicates()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# ### Шаг 3. Исследуйте данные и ответьте на вопросы

# %% [markdown]
# #### 3.1 Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.

# Создаем сводную таблицу по столбцам children и debt
data_pivot_children = data.pivot_table(index='children',values='debt',aggfunc={'size', 'sum'}).reset_index()
# Переименовываем столбцы
data_pivot_children = data_pivot_children.rename(columns={'children':'category', 'size':'total_borrowers', 'sum':'total_debtors'})
# Рассчитываем долю должников
data_pivot_children['debt_ratio'] = (data_pivot_children['total_debtors'] / data_pivot_children['total_borrowers'])*100
data_pivot_children
# Out:
#    category  total_borrowers  total_debtors  debt_ratio
# 0         0            14091           1063    7.543822
# 1         1             4808            444    9.234609
# 2         2             2052            194    9.454191
# 3         3              330             27    8.181818
# 4         4               41              4    9.756098
# 5         5                9              0    0.000000

# %% [markdown]
# **Вывод:**
#  Увеличение количества детей связано с повышением доли должников, что указывает на влияние финансовой нагрузки на возможность своевременной выплаты кредита.Категория с 5 детьми показывает нулевую долю должников, но это может быть вызвано малым размером выборки (всего 9 кредитополучателей), что делает этот показатель менее надежным для статистического вывода.

# %% [markdown]
# #### 3.2 Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
# Создаем сводную таблицу по столбцам family_status и debt
data_pivot_family_status = data.pivot_table(index='family_status',values='debt',aggfunc={'size', 'sum'}).reset_index()
# Переименовываем столбцы
data_pivot_family_status = data_pivot_family_status.rename(columns={'family_status':'category', 'size':'total_borrowers', 'sum':'total_debtors'})
# Рассчитываем долю должников
data_pivot_family_status['debt_ratio'] = (data_pivot_family_status['total_debtors'] / data_pivot_family_status['total_borrowers'])*100
data_pivot_family_status
# Out:
#                 category  total_borrowers  total_debtors  debt_ratio
# 0  Не женат / не замужем             2796            273    9.763948
# 1              в разводе             1189             84    7.064760
# 2         вдовец / вдова              951             63    6.624606
# 3       гражданский брак             4134            385    9.313014
# 4        женат / замужем            12261            927    7.560558

# %% [markdown]
# **Вывод:**
#  Люди, не состоящие в браке или состоящие в гражданском браке, имеют более высокую долю должников, что указывает на возможную финансовую нестабильность в этих группах. Люди, состоящие в официальном браке, имеют более низкую долю должников, что может свидетельствовать о большей финансовой стабильности и поддержке.

# %% [markdown]
# #### 3.3 Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
# Создаем сводную таблицу по столбцам total_income_category и debt
data_pivot_total_income_category = data.pivot_table(index='total_income_category',values='debt',aggfunc={'size', 'sum'}).reset_index()
# Переименовываем столбцы
data_pivot_total_income_category = data_pivot_total_income_category.rename(columns={'total_income_category':'category', 'size':'total_borrowers', 'sum':'total_debtors'})
# Рассчитываем долю должников
data_pivot_total_income_category['debt_ratio'] = (data_pivot_total_income_category['total_debtors'] / data_pivot_total_income_category['total_borrowers'])*100
data_pivot_total_income_category
# Out:
#   category  total_borrowers  total_debtors  debt_ratio
# 0        A               25              2    8.000000
# 1        B             5014            354    7.060231
# 2        C            15921           1353    8.498210
# 3        D              349             21    6.017192
# 4        E               22              2    9.090909

# %% [markdown]
# **Вывод:**
# Заемщики с низким доходом (категория E) имеют наибольшую долю должников, что указывает на их финансовую уязвимость. Заемщики с доходом в диапазоне 30001–50000 (категория D) имеют наименьшую долю должников, что может указывать на осторожное управление финансами в этой группе. Для заемщиков со средним и высоким доходом (категории B и C) доля должников варьируется, что может указывать на влияние других факторов, таких как личные финансовые привычки и обязательства.

# %% [markdown]
# #### 3.4 Как разные цели кредита влияют на его возврат в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
# Создаем сводную таблицу по столбцам purpose_category и debt
data_pivot_purpose_category = data.pivot_table(index='purpose_category',values='debt',aggfunc={'size', 'sum'}).reset_index()
# Переименовываем столбцы
data_pivot_purpose_category = data_pivot_purpose_category.rename(columns={'purpose_category':'category', 'size':'total_borrowers', 'sum':'total_debtors'})
# Рассчитываем долю должников
data_pivot_purpose_category['debt_ratio'] = (data_pivot_purpose_category['total_debtors'] / data_pivot_purpose_category['total_borrowers'])*100
data_pivot_purpose_category
# Out:
#                    category  total_borrowers  total_debtors  debt_ratio
# 0    операции с автомобилем             4279            400    9.347978
# 1  операции с недвижимостью            10751            780    7.255139
# 2     получение образования             3988            369    9.252758
# 3        проведение свадьбы             2313            183    7.911803

# %% [markdown]
# **Вывод:**
#  Кредиты на операции с автомобилями и получение образования имеют наибольшую долю должников, что указывает на потенциальные финансовые трудности в этих категориях. Кредиты на операции с недвижимостью имеют наименьшую долю должников, что может указывать на большую финансовую ответственность заемщиков в этой категории. Кредиты на проведение свадьбы имеют среднюю долю должников, что может указывать на более сбалансированное управление финансами в этой категории.

# %% [markdown]
# #### 3.5 Приведите возможные причины появления пропусков в исходных данных.

# %% [markdown]
# *Ответ:*
# - Человеческий фактор: при ввода или сбора данных.
# - Отсутствия данных.
# - Несоответствия формата данных или потеря данных при переносе на другое система.
# - Невозможность получить доступа для данных.

# %% [markdown]
# #### 3.6 Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.

# %% [markdown]
# *Ответ:*
# - Медиана устойчива к выбросам чем среднего.
# - Сохраняеть баланс данных при добавления нового значения.
# - При заполнени пропусков с медианой сохранять распределение ближе к исходному.
# - Очень удобно реализуются.

# %% [markdown]
# ### Шаг 4: общий вывод.

# %% [markdown]
# Напишите ваш общий вывод.
#
# В рамках данного исследовательского проекта был проведен анализ данных о возврате кредитов, основываясь на информации о клиентах банка. Начиная с предварительной обработки данных, где были выявлены и устранены пропуски, дубликаты и ошибки в данных, мы перешли к более глубокому анализу зависимостей между различными параметрами и возвратом кредита в срок.
#
# Мы рассмотрели зависимость между следующими переменными и возвратом кредита:
#
# * Количество детей в семье заемщика.
# * Семейное положение заемщика.
# * Уровень дохода заемщика.
# * Цель кредита.
#
# В результате анализа выявлены следующие ключевые моменты:
#
# * Заемщики без детей имеют ниже долю должников по сравнению с заемщиками с детьми, причем с увеличением числа детей растет и доля должников.
# * Люди, состоящие в официальном браке, имеют более низкую долю должников по сравнению с теми, кто не состоит в браке или находится в гражданском браке.
# * Высокий доход в целом связан с более низкой долей должников, но есть исключения в виде высокой доли должников среди самых богатых заемщиков.
# * Кредиты на операции с автомобилями и получение образования имеют наибольшую долю должников, в то время как кредиты на недвижимость и свадьбу имеют более низкую долю должников.
#
# <b>Рекомендации заказчику:</b><br>
# На основании выявленных зависимостей, рекомендуется следующее:
#
# 1. Улучшить процесс сбора данных о заемщиках, включая более детализированную информацию о целях кредита и их финансовом состоянии.
# 2. Разработать более точные модели скоринга, учитывающие различные факторы, такие как семейное положение, количество детей, уровень дохода и цель кредита.
# 3. Продолжать мониторинг и анализ данных для постоянного улучшения стратегий кредитного скоринга и минимизации рисков для банка.
#
# Данные рекомендации помогут банку улучшить прогнозирование возврата кредитов и снизить риски невозврата, что в свою очередь способствует более эффективному управлению финансовыми ресурсами и повышению качества обслуживания клиентов.
